# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51589/ADM-LAB/blob/main/lab_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
# Load dataset (replace with your file path or URL)

data = pd.read_csv("/content/titanic_clean.csv")

# %%
summary = data.describe()

# %%
print(summary)
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# min       0.000000     0.000000    1.000000          0.000000
# ...

# %%
print(data.describe(include=['object']))
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# Check if 'Age' column exists in the DataFrame
if 'Age' in data.columns:
    # If it exists, plot the histogram
    plt.hist(data['Age'].dropna(), bins=20, edgecolor='black', color='skyblue')
    plt.xlabel('Age')  # Add x-axis label
    plt.ylabel('Frequency')  # Add y-axis label
import matplotlib.pyplot as plt

# Check if 'Age' column exists in the DataFrame
if 'Age' in data.columns:
    # If it exists, plot the histogram
    plt.hist(data['Age'].dropna(), bins=20, edgecolor='black', color='skyblue')
    plt.xlabel('Age')  # Add x-axis label
    plt.ylabel('Frequency')  # Add y-axis label
    plt.title('Age Distribution')  # Add title
    plt.show()
else:
    print("The 'Age' column does not exist in the DataFrame.")
# Out:
# The 'Age' column does not exist in the DataFrame.

# %%
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.show()

# %%
# Bar chart for 'Pclass' (Passenger class)
plt.figure(figsize=(6, 4))

# %%
# Bar chart for 'Pclass' (Passenger class)
plt.figure(figsize=(6, 4))

# Access the column using its actual name, likely 'pclass'
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')

plt.show() # Display the plot

# %%
plt.boxplot(data['age'].dropna(), patch_artist=True,
            boxprops=dict(facecolor='lightgreen'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a5a31d0a010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a5a31b9ad50>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7a5a31ba6890>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a5a31bb5490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a5a31bb5e10>],
#  'means': []}

# %%
plt.title('Box Plot of Age')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age')

# %%
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.figure(figsize=(6, 4))

# Access the column using its actual name, likely 'pclass'
data['age'].value_counts().plot(kind='bar', color='lightcoral')

plt.show()

# %%
plt.show()

# %%
import seaborn as sns

# %%
# Replace with the actual column names from your DataFrame
sns.pairplot(data[['age', 'fare', 'sibsp', 'parch']].dropna())
plt.show()

# %%
correlation_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.figure(figsize=(6, 4))

# Access the column using its actual name, likely 'pclass'
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')

plt.show()

# %%
# Check if 'Survived' column exists in the DataFrame
print(data.columns)  # Print the column names to verify

# If the column name is different, correct it in the countplot function
# For example, if the column name is 'survived', use:
sns.countplot(x='survived', data=data, palette='Set2')
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')
# <ipython-input-38-d13e712299e4>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='survived', data=data, palette='Set2')
# <Axes: xlabel='survived', ylabel='count'>

# %%
plt.title('Survival Count')
# Out:
# Text(0.5, 1.0, 'Survival Count')

# %%
plt.xlabel('Survived')
# Out:
# Text(0.5, 0, 'Survived')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.show()

# %%
# Violin plot for 'Age' across 'Pclass'
# Correct the column name to 'age' if it's in lowercase
sns.violinplot(x='pclass', y='age', data=data, palette='muted')
plt.title('Age Distribution by Passenger Class')
plt.show()
# Out:
# <ipython-input-45-c710bb8df7bf>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='pclass', y='age', data=data, palette='muted')

# %%
# Importing necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Generate Statistical Summary
print("Statistical Summary:")
print(data.describe())
# Out:
# Statistical Summary:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# ...

# %%
# Summary of categorical columns
print("\nCategorical Summary:")
print(data.describe(include=['object']))
# Out:
# Categorical Summary:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
# 2. Data Visualizations using Matplotlib
# Histogram for 'Age'
# Use 'age' instead of 'Age' to access the column
plt.hist(data['age'].dropna(), bins=20, edgecolor='black', color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar chart for 'Pclass' (Passenger class)
plt.figure(figsize=(6, 4))
# Access the column using its actual name, likely 'pclass'
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Passenger Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show() # Display the plot

# %%
plt.show()

# %%
# Box plot for 'Age'
plt.figure(figsize=(6, 4))
plt.boxplot(data['age'].dropna(), patch_artist=True, # Changed 'Age' to 'age'
            boxprops=dict(facecolor='lightgreen'))
plt.title('Box Plot of Age')
plt.ylabel('Age')
plt.show()

# %%
# 3. Data Visualizations using Seaborn
# Pair plot to visualize relationships between numerical features
# Change column names to lowercase
sns.pairplot(data[['age', 'fare', 'sibsp', 'parch']].dropna())
plt.show()

# %%
# Correlation heatmap
correlation_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()  # Changed column names to lowercase
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Count plot for 'Survived'
# Correct the column name to 'survived' if it's in lowercase
sns.countplot(x='survived', data=data, palette='Set2')
plt.title('Survival Count')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-64-3cf2ddc3ffce>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='survived', data=data, palette='Set2')

# %%
nna# Violin plot for 'Age' by 'Pclass'
# Correct the column name to 'pclass' if it's in lowercase
sns.violinplot(x='pclass', y='age', data=data, palette='muted')
plt.title('Age Distribution by Passenger Class')
plt.show()
# Out:
# <ipython-input-66-bd00baa601b0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='pclass', y='age', data=data, palette='muted')
